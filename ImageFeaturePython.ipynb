# %%
import cv2
import numpy as np
img = cv2.imread('/Users/anubhav/Desktop/SampleJPEG.jpg')

# %%
import cv2
import numpy as np
from PIL import Image

img_file = '/Users/anubhav/Desktop/SampleJPEG.jpg'
img = cv2.imread(img_file, cv2.IMREAD_COLOR)           # rgb
alpha_img = cv2.imread(img_file, cv2.IMREAD_UNCHANGED) # rgba
gray_img = cv2.imread(img_file, cv2.IMREAD_GRAYSCALE)  # grayscale

im = Image.open(img_file)
a = np.asarray(img_file)
window_size = (5,5,3)
windows = sliding_window(a, window_size)
print(windows.shape)
#im_read = Image.read()

print(type(img))
print('RGB shape: ', img.shape)        # Rows, cols, channels
print('ARGB shape:', alpha_img.shape)
print('Gray shape:', gray_img.shape)
print ('img.dtype: ', img.dtype)
print ('img.size: ', img.size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-567ae0dd8674> in <module>
#      11 a = np.asarray(img_file)
#      12 window_size = (5,5,3)
# ---> 13 windows = sliding_window(a, window_size)
#      14 print(windows.shape)
#      15 #im_read = Image.read()
#
# NameError: name 'sliding_window' is not defined

# %%
import pandas as pd
import numpy as np
from skimage.transform import resize
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow
img_file = '/Users/anubhav/Desktop/Pics/05_binladen_part3.jpg'
print(img_file)
image = imread(img_file, as_gray=False)
imshow(image)
image.shape
np.array(image)
img_resized = resize(image, (5,5))
image_array = np.array(img_resized)
image_array
# Out:
# /Users/anubhav/Desktop/Pics/05_binladen_part3.jpg
# array([[[0.6372549 , 0.5       , 0.20588235],
#         [0.61960784, 0.49098039, 0.20254902],
#         [0.60098039, 0.44705882, 0.21666667],
#         [0.6045098 , 0.44901961, 0.21176471],
#         [0.6       , 0.43745098, 0.18823529]],
#
#        [[0.51156863, 0.39019608, 0.16078431],
#         [0.45490196, 0.40196078, 0.21235294],
#         [0.50098039, 0.37843137, 0.22843137],
#         [0.44627451, 0.33980392, 0.20392157],
#         [0.47607843, 0.36666667, 0.21156863]],
#
#        [[0.47843137, 0.31980392, 0.1745098 ],
#         [0.40588235, 0.37254902, 0.25215686],
#         [0.43921569, 0.35588235, 0.23333333],
#         [0.43333333, 0.31823529, 0.18039216],
#         [0.4427451 , 0.31176471, 0.20156863]],
#
#        [[0.49607843, 0.30392157, 0.24921569],
#         [0.52215686, 0.35803922, 0.25039216],
#         [0.55098039, 0.40196078, 0.20196078],
#         [0.51960784, 0.35941176, 0.18235294],
# ...
